# %%
import pandas as pd

# %%
root_path = r'.'

# %%
file = os.path.join(root_path,'强赎数据20211014.xlsx')
df = pd.read_excel(file)

# %%
df.head()
# Out:
#      code      date  down_shadow  line_type_  percent  up_shadow  \
# 0  110030  20191210        -0.18        True     0.02       0.02
# 1  110031  20210528        -0.08        True    -0.09       0.06
# 2  110032  20190319        -1.17       False    -1.36       5.55
# 3  110039  20180706        -0.64        True    -0.23       6.96
# 4  110040  20190731        -2.07        True     0.47       2.54
#
#    wave_percent  name   chgPct7  remain_size
# 0          0.20  格力转债  0.000473     4.002523
# 1          0.14  航信转债 -0.001030    23.986811
# 2          6.71  三一转债  0.094951     0.225395
# 3          7.60  宝信转债 -0.019351     0.287358
# 4          4.62  生益转债  0.251008     0.101478

# %%
df['date']=pd.to_datetime(df['date'],format="%Y%m%d")

# %%
df.head()
# Out:
#      code       date  down_shadow  line_type_  percent  up_shadow  \
# 0  110030 2019-12-10        -0.18        True     0.02       0.02
# 1  110031 2021-05-28        -0.08        True    -0.09       0.06
# 2  110032 2019-03-19        -1.17       False    -1.36       5.55
# 3  110039 2018-07-06        -0.64        True    -0.23       6.96
# 4  110040 2019-07-31        -2.07        True     0.47       2.54
#
#    wave_percent  name   chgPct7  remain_size
# 0          0.20  格力转债  0.000473     4.002523
# 1          0.14  航信转债 -0.001030    23.986811
# 2          6.71  三一转债  0.094951     0.225395
# 3          7.60  宝信转债 -0.019351     0.287358
# 4          4.62  生益转债  0.251008     0.101478

# %%
df.set_index('date',inplace=True,drop=True)

# %%
df.head()
# Out:
#               code  down_shadow  line_type_  percent  up_shadow  wave_percent  \
# date
# 2019-12-10  110030         0.02        True     0.02      -0.16          0.20
# 2021-05-28  110031         0.06        True    -0.09      -0.18          0.14
# 2019-03-19  110032         5.55       False    -1.36      -2.52          6.71
# 2018-07-06  110039         6.96        True    -0.23      -0.87          7.60
# 2019-07-31  110040         2.54        True     0.47      -1.61          4.62
#
#             name   chgPct7  remain_size
# date
# 2019-12-10  格力转债  0.000473     4.002523
# 2021-05-28  航信转债 -0.001030    23.986811
# 2019-03-19  三一转债  0.094951     0.225395
# 2018-07-06  宝信转债 -0.019351     0.287358
# 2019-07-31  生益转债  0.251008     0.101478

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 144 entries, 2019-12-10 to 2021-09-06
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   code          144 non-null    int64
#  1   down_shadow   144 non-null    float64
#  2   line_type_    144 non-null    bool
#  3   percent       144 non-null    float64
#  4   up_shadow     144 non-null    float64
#  5   wave_percent  144 non-null    float64
#  6   name          144 non-null    object
#  7   chgPct7       144 non-null    float64
#  8   remain_size   144 non-null    float64
# dtypes: bool(1), float64(6), int64(1), object(1)
# memory usage: 10.3+ KB

# %%
df.sort_index(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 144 entries, 2018-07-06 to 2021-09-28
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   code          144 non-null    int64
#  1   down_shadow   144 non-null    float64
#  2   line_type_    144 non-null    bool
#  3   percent       144 non-null    float64
#  4   up_shadow     144 non-null    float64
#  5   wave_percent  144 non-null    float64
#  6   name          144 non-null    object
#  7   chgPct7       144 non-null    float64
#  8   remain_size   144 non-null    float64
# dtypes: bool(1), float64(6), int64(1), object(1)
# memory usage: 10.3+ KB

# %%
df.tail()
# Out:
#               code  down_shadow  line_type_  percent  up_shadow  wave_percent  \
# date
# 2021-09-08  123079        10.95       False    -2.73      -3.71         11.94
# 2021-09-09  113612        11.00        True     7.17       0.71         17.46
# 2021-09-14  123030         9.41       False    -0.55      -1.19         10.04
# 2021-09-23  113572         7.55       False    -2.59      -4.62          9.59
# 2021-09-28  113014         1.58        True     6.76      -2.51         10.85
#
#             name   chgPct7  remain_size
# date
# 2021-09-08  运达转债  0.234062     0.431155
# 2021-09-09  永冠转债  0.097401     0.147570
# 2021-09-14  九洲转债  0.021782     0.544629
# 2021-09-23  三祥转债 -0.072741     0.088365
# 2021-09-28  林洋转债  0.066013     0.184097

# %%
df['chgPct7'].argmin()
# Out:
# 37

# %%
df.iloc[37]
# Out:
# code              113510
# down_shadow         5.76
# line_type_         False
# percent             1.71
# up_shadow          -3.49
# wave_percent       10.96
# name                再升转债
# chgPct7        -0.235967
# remain_size          0.2
# Name: 2020-03-24 00:00:00, dtype: object

# %%
df['chgPct7']=df['chgPct7']*100

# %%
df['line_type_'].value_counts()
# Out:
# False    75
# True     70
# Name: line_type_, dtype: int64

# %%
df[df['chgPct7']>=0].count()
# Out:
# code            63
# down_shadow     63
# line_type_      63
# percent         63
# up_shadow       63
# wave_percent    63
# name            63
# chgPct7         63
# remain_size     63
# dtype: int64

# %%
len(df)
# Out:
# 145

# %%
63/145
# Out:
# 0.43448275862068964

# %%
df['chgPct7'].mean()
# Out:
# -0.3296854166666668

# %%
df['chgPct7'].max()
# Out:
# 25.1008

# %%
df[df['code']=='123079']
# Out:
#               code  down_shadow  line_type_  percent  up_shadow  wave_percent  \
# date
# 2021-09-08  123079        10.95       False    -2.73      -3.71         11.94
#
#             name  chgPct7  remain_size
# date
# 2021-09-08  运达转债  23.4062     0.431155

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 144 entries, 2018-07-06 to 2021-09-28
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   code          144 non-null    int64
#  1   down_shadow   144 non-null    float64
#  2   line_type_    144 non-null    bool
#  3   percent       144 non-null    float64
#  4   up_shadow     144 non-null    float64
#  5   wave_percent  144 non-null    float64
#  6   name          144 non-null    object
#  7   chgPct7       144 non-null    float64
#  8   remain_size   144 non-null    float64
# dtypes: bool(1), float64(6), int64(1), object(1)
# memory usage: 15.3+ KB

# %%
df['code']=df['code'].astype(str)

# %%
t=df[df['chgPct7']>=0]['percent']

# %%
t[t<0].count()
# Out:
# 17

# %%
len(t)
# Out:
# 63

# %%
index = t[t>0]

# %%
type(index)
# Out:
# pandas.core.series.Series

# %%
df.iloc[index]
# Out:
#               code  down_shadow  line_type_  percent  up_shadow  wave_percent  \
# date
# 2019-04-26  123008         5.34       False    -3.35      -4.30          6.29
# 2018-07-06  110039         6.96        True    -0.23      -0.87          7.60
# 2018-07-06  110039         6.96        True    -0.23      -0.87          7.60
# 2018-07-06  110039         6.96        True    -0.23      -0.87          7.60
# 2018-07-06  110039         6.96        True    -0.23      -0.87          7.60
# 2018-07-06  110039         6.96        True    -0.23      -0.87          7.60
# 2019-01-28  113010         0.01        True     0.05      -0.02          0.08
# 2018-07-06  110039         6.96        True    -0.23      -0.87          7.60
# 2018-08-14  123005         2.10        True    -1.31      -2.52          3.31
# 2019-01-28  113010         0.01        True     0.05      -0.02          0.08
# 2019-04-23  113512         1.83        True    -1.13      -1.76          2.46
# 2018-08-14  123005         2.10        True    -1.31      -2.52          3.31
# 2018-08-14  123005         2.10        True    -1.31      -2.52          3.31
# 2019-05-10  123006         3.34        True     5.07       1.01          7.41
# 2019-01-28  113010         0.01        True     0.05      -0.02          0.08
# 2018-07-06  110039         6.96        True    -0.23      -0.87          7.60
# 2019-04-26  113506         2.14       False    -1.17      -7.49          8.46
# 2018-07-06  110039         6.96        True    -0.23      -0.87          7.60
# 2018-08-14  123005         2.10        True    -1.31      -2.52          3.31
# 2019-01-28  113010         0.01        True     0.05      -0.02          0.08
# 2018-07-06  110039         6.96        True    -0.23      -0.87          7.60
# 2018-08-14  123005         2.10        True    -1.31      -2.52          3.31
# 2019-03-19  110032         5.55       False    -1.36      -2.52          6.71
# 2018-08-14  123005         2.10        True    -1.31      -2.52          3.31
# 2019-04-26  113506         2.14       False    -1.17      -7.49          8.46
# 2019-01-28  113010         0.01        True     0.05      -0.02          0.08
# 2019-04-26  123008         5.34       False    -3.35      -4.30          6.29
# 2018-07-06  110039         6.96        True    -0.23      -0.87          7.60
# 2018-07-06  110039         6.96        True    -0.23      -0.87          7.60
# 2019-05-10  123006         3.34        True     5.07       1.01          7.41
# 2018-07-06  110039         6.96        True    -0.23      -0.87          7.60
# 2019-01-28  113010         0.01        True     0.05      -0.02          0.08
# 2019-01-28  113010         0.01        True     0.05      -0.02          0.08
# 2019-07-04  113513         2.55       False    -2.86      -4.05          3.74
# 2019-04-23  113512         1.83        True    -1.13      -1.76          2.46
# 2019-07-31  110040         2.54        True     0.47      -1.61          4.62
# 2019-07-04  113513         2.55       False    -2.86      -4.05          3.74
# 2019-03-19  110032         5.55       False    -1.36      -2.52          6.71
# 2019-05-16  113018         0.19        True     0.47      -0.70          1.37
# 2019-05-10  123006         3.34        True     5.07       1.01          7.41
# 2019-01-28  113010         0.01        True     0.05      -0.02          0.08
# 2019-05-10  123006         3.34        True     5.07       1.01          7.41
# 2019-04-23  113512         1.83        True    -1.13      -1.76          2.46
# 2019-05-10  123006         3.34        True     5.07       1.01          7.41
# 2019-04-26  113506         2.14       False    -1.17      -7.49          8.46
#
#             name  chgPct7  remain_size
# date
# 2019-04-26  康泰转债   0.9928     0.068735
# 2018-07-06  宝信转债  -1.9351     0.287358
# 2018-07-06  宝信转债  -1.9351     0.287358
# 2018-07-06  宝信转债  -1.9351     0.287358
# 2018-07-06  宝信转债  -1.9351     0.287358
# 2018-07-06  宝信转债  -1.9351     0.287358
# 2019-01-28  江南转债  -2.8304     0.240321
# 2018-07-06  宝信转债  -1.9351     0.287358
# 2018-08-14  万信转债   1.1797     0.171000
# 2019-01-28  江南转债  -2.8304     0.240321
# 2019-04-23  景旺转债  -1.9085     0.176180
# 2018-08-14  万信转债   1.1797     0.171000
# 2018-08-14  万信转债   1.1797     0.171000
# 2019-05-10  东财转债   8.6965     0.999724
# 2019-01-28  江南转债  -2.8304     0.240321
# 2018-07-06  宝信转债  -1.9351     0.287358
# 2019-04-26  鼎信转债  -3.9485     0.122682
# 2018-07-06  宝信转债  -1.9351     0.287358
# 2018-08-14  万信转债   1.1797     0.171000
# 2019-01-28  江南转债  -2.8304     0.240321
# 2018-07-06  宝信转债  -1.9351     0.287358
# 2018-08-14  万信转债   1.1797     0.171000
# 2019-03-19  三一转债   9.4951     0.225395
# 2018-08-14  万信转债   1.1797     0.171000
# 2019-04-26  鼎信转债  -3.9485     0.122682
# 2019-01-28  江南转债  -2.8304     0.240321
# 2019-04-26  康泰转债   0.9928     0.068735
# 2018-07-06  宝信转债  -1.9351     0.287358
# 2018-07-06  宝信转债  -1.9351     0.287358
# 2019-05-10  东财转债   8.6965     0.999724
# 2018-07-06  宝信转债  -1.9351     0.287358
# 2019-01-28  江南转债  -2.8304     0.240321
# 2019-01-28  江南转债  -2.8304     0.240321
# 2019-07-04  安井转债  -3.6944     0.038700
# 2019-04-23  景旺转债  -1.9085     0.176180
# 2019-07-31  生益转债  25.1008     0.101478
# 2019-07-04  安井转债  -3.6944     0.038700
# 2019-03-19  三一转债   9.4951     0.225395
# 2019-05-16  常熟转债   1.8808     0.155491
# 2019-05-10  东财转债   8.6965     0.999724
# 2019-01-28  江南转债  -2.8304     0.240321
# 2019-05-10  东财转债   8.6965     0.999724
# 2019-04-23  景旺转债  -1.9085     0.176180
# 2019-05-10  东财转债   8.6965     0.999724
# 2019-04-26  鼎信转债  -3.9485     0.122682

# %%
df[df['code']=='110039']
# Out:
#               code  down_shadow  line_type_  percent  up_shadow  wave_percent  \
# date
# 2018-07-06  110039         6.96        True    -0.23      -0.87           7.6
#
#             name  chgPct7  remain_size
# date
# 2018-07-06  宝信转债  -1.9351     0.287358

# %%
t
# Out:
# date
# 2018-08-14   -1.31
# 2019-03-19   -1.36
# 2019-04-26   -3.35
# 2019-05-10    5.07
# 2019-05-16    0.47
#               ...
# 2021-09-06    4.94
# 2021-09-08   -2.73
# 2021-09-09    7.17
# 2021-09-14   -0.55
# 2021-09-28    6.76
# Name: percent, Length: 63, dtype: float64

# %%
df['chgPct6']=df['chgPct7']-df['percent']

# %%
df[df['chgPct6']<0].count()
# Out:
# code       78
# 下影线        78
# 阳线         78
# 最后一天涨幅     78
# 上影线        78
# 波动         78
# name       78
# 溢价率        78
# 最近7天涨幅     78
# 剩余规模       78
# chgPct6    78
# dtype: int64

# %%
last_week = df[df['chgPct6']>=0]
up_last_day = []
down_last_day=[]
for index,row in last_week.iterrows():
    if row['percent']>0:
        up_last_day.append(row)
    else:
        down_last_day.append(row)

# %%
up_df = pd.DataFrame(up_last_day)
down_df = pd.DataFrame(down_last_day)

# %%
up_df
# Out:
#               code  down_shadow  line_type_  percent  up_shadow  wave_percent  \
# 2019-05-10  123006         3.34        True     5.07       1.01          7.41
# 2019-05-16  113018         0.19        True     0.47      -0.70          1.37
# 2019-07-31  110040         2.54        True     0.47      -1.61          4.62
# 2019-09-03  113015         2.15        True     0.61      -2.12          4.89
# 2019-10-09  128027         4.20        True     0.70      -1.75          6.66
# 2019-10-10  123001         0.22        True     0.45      -1.13          1.80
# 2019-10-14  127009         0.79        True     2.90       0.31          3.38
# 2019-12-10  110030         0.02        True     0.02      -0.16          0.20
# 2019-12-16  110049         2.30        True     1.87      -0.52          4.68
# 2020-02-05  113523         2.85        True     2.68      -4.42          9.95
# 2020-02-05  128068         4.75        True     4.80      -0.03          9.58
# 2020-02-12  128060         0.56        True     1.28      -1.33          3.17
# 2020-03-27  128016         2.80        True     1.02      -0.27          4.10
# 2020-04-08  110050         6.69        True     7.73       1.39         13.02
# 2020-06-17  113515         1.30        True     2.94      -1.06          5.29
# 2020-07-14  128077         9.24       False     0.22      -2.54         12.01
# 2020-07-15  113551        24.49        True     6.37      -2.50         33.36
# 2020-08-03  128080         1.76       False     0.23      -9.27         11.26
# 2020-08-06  113552        12.33        True     1.53      -4.76         18.62
# 2020-08-18  128089         1.11        True     2.20      -1.33          4.64
# 2020-08-18  113558         6.36        True     0.35      -1.85          8.56
# 2020-08-27  123041         1.04        True     1.04      -0.27          2.35
# 2020-09-03  113019         5.71        True     3.13      -0.77          9.61
# 2020-11-09  128098         2.32        True     1.18      -2.35          5.85
# 2020-11-26  113521        12.41        True     6.32      -2.26         21.00
# 2020-12-03  113555         8.83        True     2.11      -1.01         11.95
# 2020-12-18  113562        22.92        True     5.65       0.10         28.47
# 2021-01-06  128019         4.47       False     0.55      -0.94          5.97
# 2021-01-13  113032         8.66       False     0.17      -2.18         11.01
# 2021-02-22  128110         5.38        True     7.98     -21.65         35.02
# 2021-03-05  113590        11.95        True     0.29      -1.55         13.79
# 2021-03-05  128028         1.83        True     2.16      -3.67          7.66
# 2021-03-18  113029         0.34        True     2.96      -1.75          5.05
# 2021-03-30  113038         1.03        True     9.12      -0.69         10.84
# 2021-06-25  113041         0.44        True     4.35       0.46          4.34
# 2021-06-25  113559        19.33        True    10.76      -0.56         30.65
# 2021-06-28  123029         2.38        True     9.35       1.43         10.30
# 2021-07-15  127023         0.63        True     3.43      -0.43          4.49
# 2021-08-02  113040         0.96        True     8.42      -0.60          9.98
# 2021-08-24  128064        11.75        True     7.07      -0.32         19.14
# 2021-08-30  123033         2.91        True     2.94      -0.13          5.98
# 2021-09-02  113012         7.49        True     7.01      -0.41         14.92
# 2021-09-06  123094         6.26        True     4.94      -3.61         14.81
# 2021-09-09  113612        11.00        True     7.17       0.71         17.46
# 2021-09-28  113014         1.58        True     6.76      -2.51         10.85
#
#              name  chgPct7  remain_size
# 2019-05-10   东财转债   8.6965     0.999724
# 2019-05-16   常熟转债   1.8808     0.155491
# 2019-07-31   生益转债  25.1008     0.101478
# 2019-09-03   隆基转债   8.3175     0.194473
# 2019-10-09   崇达转债   0.7041     1.229593
# 2019-10-10   蓝标转债   1.6207     0.020195
# 2019-10-14   冰轮转债   3.7758     0.015970
# 2019-12-10   格力转债   0.0473     4.002523
# 2019-12-16   海尔转债  11.4093     0.091358
# 2020-02-05   伟明转债  18.9160     0.027317
# 2020-02-05   和而转债   9.8072     0.939994
# 2020-02-12   中装转债   1.2766     0.150120
# 2020-03-27   雨虹转债   2.0845     1.598509
# 2020-04-08   佳都转债  18.5198     0.183347
# 2020-06-17   高能转债  11.6670     0.079502
# 2020-07-14   华夏转债  13.5864     0.173569
# 2020-07-15   福特转债   7.3545     0.035742
# 2020-08-03   顺丰转债   6.2293     1.063514
# 2020-08-06   克来转债  15.6737     0.037122
# 2020-08-18   麦米转债   0.5913     1.608151
# 2020-08-18   日月转债   4.8362     0.041749
# 2020-08-27   东财转2   1.4114     0.498685
# 2020-09-03   玲珑转债   6.4890     0.073730
# 2020-11-09   康弘转债   3.2298     3.958178
# 2020-11-26   科森转债   5.3411     0.080263
# 2020-12-03   振德转债   3.7413     0.028216
# 2020-12-18   璞泰转债   7.7111     0.188299
# 2021-01-06   久立转2   7.0146     0.296511
# 2021-01-13  桐20转债   8.5642     0.076143
# 2021-02-22   永兴转债   1.6312     0.203087
# 2021-03-05   海容转债   4.0226     0.029141
# 2021-03-05   赣锋转债   0.2025     0.539134
# 2021-03-18   明阳转债   2.4274     0.051040
# 2021-03-30  隆20转债  11.5640     0.236243
# 2021-06-25   紫金转债   3.5054     0.194681
# 2021-06-25   永创转债  14.8470     0.053363
# 2021-06-28   英科转债  10.1180     0.089749
# 2021-07-15   华菱转2   7.8391     2.438215
# 2021-08-02   星宇转债   4.7809     0.075537
# 2021-08-24   司尔转债  13.4504     0.229420
# 2021-08-30   金力转债   4.4424     0.590273
# 2021-09-02   骆驼转债   1.6898     0.023375
# 2021-09-06   星源转2  16.8968     0.531776
# 2021-09-09   永冠转债   9.7401     0.147570
# 2021-09-28   林洋转债   6.6013     0.184097

# %%
len(down_df)
# Out:
# 30

# %%
len(up_df)
# Out:
# 35

# %%
df.head()
# Out:
#               code  down_shadow  line_type_  percent  up_shadow  wave_percent  \
# date
# 2018-07-06  110039         6.96        True    -0.23      -0.87          7.60
# 2018-08-14  123005         2.10        True    -1.31      -2.52          3.31
# 2019-01-28  113010         0.01        True     0.05      -0.02          0.08
# 2019-03-19  110032         5.55       False    -1.36      -2.52          6.71
# 2019-04-23  113512         1.83        True    -1.13      -1.76          2.46
#
#             name  chgPct7  remain_size
# date
# 2018-07-06  宝信转债  -1.9351     0.287358
# 2018-08-14  万信转债   1.1797     0.171000
# 2019-01-28  江南转债  -2.8304     0.240321
# 2019-03-19  三一转债   9.4951     0.225395
# 2019-04-23  景旺转债  -1.9085     0.176180

# %%
df['wave_percent'].mean()
# Out:
# 8.166111111111114

# %%
df.groupby('line_type_').count()
# Out:
#             code  down_shadow  percent  up_shadow  wave_percent  name  \
# line_type_
# False         74           74       74         74            74    74
# True          70           70       70         70            70    70
#
#             chgPct7  remain_size
# line_type_
# False            74           74
# True             70           70

# %%
df[df['line_type_']==True]['code'].values
# Out:
# array(['110039', '123005', '113010', '113512', '123006', '113018',
#        '110040', '113015', '127010', '128027', '123001', '127009',
#        '110030', '110049', '113533', '113523', '128068', '128060',
#        '128061', '113539', '123009', '113540', '128016', '110050',
#        '113503', '113515', '128054', '113551', '113552', '128059',
#        '128089', '113558', '128045', '128086', '123041', '113031',
#        '113019', '113028', '128098', '113020', '113521', '113555',
#        '113562', '113587', '128110', '128115', '123017', '128065',
#        '128112', '113590', '113592', '128028', '113029', '113038',
#        '110031', '113041', '113559', '123029', '123058', '127023',
#        '128032', '113611', '113040', '123007', '128064', '123033',
#        '113012', '123094', '113612', '113014'], dtype=object)

# %%
df.resample('M').count()['code'].plot(kind='bar')

# %%
df.to_pickle('强赎数据.pkl')

# %%
df=df.rename(columns={
    'line_type_':'阳线',
'remain_size':'剩余规模',
'wave_percent':'波动','up_shadow':'上影线',
'down_shadow':'下影线','chgPct7':'最近7天涨幅',
'percent':'最后一天涨幅','bondPremRatio':'溢价率'})

# %%
df.head()
# Out:
#               code   下影线     阳线  最后一天涨幅   上影线    波动  name      溢价率  最近7天涨幅  \
# date
# 2018-07-06  110039 -0.64   True   -0.23  6.96  7.60  宝信转债  -1.3091 -1.9351
# 2018-08-14  123005 -1.22   True   -1.31  2.10  3.31  万信转债  -0.2300  1.1797
# 2019-01-28  113010 -0.07   True    0.05  0.01  0.08  江南转债  64.5521 -2.8304
# 2019-03-19  110032 -1.17  False   -1.36  5.55  6.71  三一转债  -0.2615  9.4951
# 2019-04-23  113512 -0.63   True   -1.13  1.83  2.46  景旺转债  -0.6551 -1.9085
#
#                 剩余规模  chgPct6
# date
# 2018-07-06  0.287358  -1.7051
# 2018-08-14  0.171000   2.4897
# 2019-01-28  0.240321  -2.8804
# 2019-03-19  0.225395  10.8551
# 2019-04-23  0.176180  -0.7785

# %%
df=df.rename(columns={
'bondPremRatio':'溢价率'})

# %%
df.to_excel('强赎数据latest.xlsx',encoding='utf8')

# %%
df['阳线'].value_counts()
# Out:
# False    75
# True     68
# Name: 阳线, dtype: int64

# %%
68/75
# Out:
# 0.9066666666666666

# %%
68/143
# Out:
# 0.4755244755244755

# %%
df[df['最后一天涨幅']>=0]['code'].count()
# Out:
# 68

# %%
69/144
# Out:
# 0.4791666666666667

# %%
df['波动'].mean()
# Out:
# 8.166111111111114

# %%
print(df['最后一天涨幅'].max(),'%')
print(df.iloc[df['最后一天涨幅'].argmax()]['name'])
# Out:
# 10.76 %
# 永创转债

# %%
print(df['最后一天涨幅'].min(),'%')
print(df.iloc[df['最后一天涨幅'].argmin()]['name'])
# Out:
# -12.05 %
# 千禾转债

# %%
df['下影线'].mean()
# Out:
# -2.9171034482758604

# %%
df['上影线'].mean()
# Out:
# 5.2307586206896595

# %%
def ratio(x):
    return x/(0.203618+1)

# %%
ratio(136.66)
# Out:
# 113.54100719663546

# %%
(136.66-109.67)/109.67
# Out:
# 0.24610194219020692

# %%
ratio()

# %%
df['最后7天涨幅'].mean()
# Out:
# -0.3264169014084509

# %%
df.tail()
# Out:
#               code  down_shadow  line_type_  percent  up_shadow  wave_percent  \
# date
# 2021-09-09  113612        -6.46        True     7.17      11.00         17.46
# 2021-09-14  123030        -0.64       False    -0.55       9.41         10.04
# 2021-09-23  113572        -2.03       False    -2.59       7.55          9.59
# 2021-09-28  113014        -9.27        True     6.76       1.58         10.85
# 2021-10-11  123068        -1.62       False    -1.76       3.97          5.58
#
#             name  chgPct7  remain_size  chgPct6
# date
# 2021-09-09  永冠转债   9.7401     0.147570   2.5701
# 2021-09-14  九洲转债   2.1782     0.544629   2.7282
# 2021-09-23  三祥转债  -7.2741     0.088365  -4.6841
# 2021-09-28  林洋转债   6.6013     0.184097  -0.1587
# 2021-10-11  弘信转债  -1.7626     0.814960  -0.0026

# %%
df[df['最后一天涨幅']>=0]['code'].count()
# Out:
# 69

# %%
69/145
# Out:
# 0.47586206896551725

# %%
df['波动'].mean()
# Out:
# 8.148275862068967

# %%
df[df['溢价率']>2]
# Out:
#               code    下影线    阳线  最后一天涨幅    上影线     波动  name     溢价率   最近7天涨幅  \
# date
# 2019-12-10  110030  -0.18  True    0.02   0.02   0.20  格力转债  9.8648   0.0473
# 2020-07-15  113551  -8.87  True    6.37  24.49  33.36  福特转债  2.2958   7.3545
# 2020-11-26  113521  -8.59  True    6.32  12.41  21.00  科森转债  3.9009   5.3411
# 2021-06-25  113559 -11.32  True   10.76  19.33  30.65  永创转债  5.5266  14.8470
#
#                 剩余规模  chgPct6
# date
# 2019-12-10  4.002523   0.0273
# 2020-07-15  0.035742   0.9845
# 2020-11-26  0.080263  -0.9789
# 2021-06-25  0.053363   4.0870

# %%
df[df['name']=='电气转债']
# Out:
#               code   下影线     阳线  最后一天涨幅   上影线    波动  name     溢价率  最近7天涨幅  \
# date
# 2021-01-18  113008 -0.05  False   -0.32  0.44  0.49  电气转债  0.0443  -1.735
#
#                 剩余规模  chgPct6
# date
# 2021-01-18  20.13482   -1.415

# %%
df.to_excel('末日轮数据.xlsx',encoding='utf8')

# %%
force_redom = df[~df['code'].isin(['113010','110031','110030'])]

# %%
df=force_redom

# %%
df_=pd.read_excel('末日轮数据.xlsx')

# %%
df_[df_['溢价率']<-5]
# Out:
# Empty DataFrame
# Columns: [date, code, 下影线, 阳线, 最后一天涨幅, 上影线, 波动, name, 溢价率, 最近7天涨幅, 剩余规模, chgPct6]
# Index: []

# %%
df['溢价率'].describe()
# Out:
# count    142.000000
# mean      -0.785982
# std        0.975234
# min       -3.589400
# 25%       -1.261250
# 50%       -0.743850
# 75%       -0.386575
# max        5.526600
# Name: 溢价率, dtype: float64

# %%
df[df['溢价率']>5]
# Out:
#               code    下影线    阳线  最后一天涨幅    上影线     波动  name     溢价率  最近7天涨幅  \
# date
# 2021-06-25  113559 -11.32  True   10.76  19.33  30.65  永创转债  5.5266  14.847
#
#                 剩余规模  chgPct6
# date
# 2021-06-25  0.053363    4.087

# %%
df.iloc[df['溢价率'].argmax()]
# Out:
# code         113559
# 下影线          -11.32
# 阳线             True
# 最后一天涨幅        10.76
# 上影线           19.33
# 波动            30.65
# name           永创转债
# 溢价率          5.5266
# 最近7天涨幅       14.847
# 剩余规模       0.053363
# chgPct6       4.087
# Name: 2021-06-25 00:00:00, dtype: object

# %%
df['剩余规模'].mean()
# Out:
# 0.5241408306338029
