# %%
from setting import get_engine
import pandas as pd

# %%
engine = get_engine('db_stock','local')

# %%
df = pd.read_sql('tb_bond_jisilu',con=engine)
# Out:
# c:\python3_64\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xD6\\xD0\\xB9\\xFA\\xB1\\xEA...' for column 'VARIABLE_VALUE' at row 480")
#   result = self._query(query)

# %%
df.head()
# Out:
#     可转债代码 可转债名称   可转债价格  正股名称    正股代码   正股现价        ...         下调次数  转债剩余占总市值比   剩余规模   发行规模  股东配售率              更新日期
# 0  127008  特发转债  185.60  特发信息  000070  16.29        ...            0        4.1  4.194  4.194  45.92  2019-03-13 15:31
# 1  110050  佳都转债  135.49  佳都科技  600728  11.90        ...            0        4.5  8.747  8.747  14.08  2019-03-13 15:31
# 2  128053  尚荣转债  119.50  尚荣医疗  002551   6.41        ...            0       16.6  7.500  7.500  15.80  2019-03-13 15:31
# 3  123018  溢利转债  114.45   溢多利  300381  10.27        ...            0       15.9  6.650  6.650  35.63  2019-03-13 15:31
# 4  123016  洲明转债  135.64  洲明科技  300232  13.63        ...            0        5.3  5.480  5.480  33.98  2019-03-13 15:31
#
# [5 rows x 29 columns]

# %%
zg_list = list(df['正股代码'].values)

# %%
zg_list
# Out:
# ['000070',
#  '600728',
#  '002551',
#  '300381',
#  '300232',
#  '603305',
#  '002783',
#  '000811',
#  '603313',
#  '603626',
#  '002131',
#  '603668',
#  '600567',
#  '601311',
#  '300601',
#  '300057',
#  '300058',
#  '002446',
#  '300409',
#  '600372',
#  '601128',
#  '300059',
#  '603228',
#  '002548',
#  '002224',
#  '000665',
#  '603323',
#  '300297',
#  '600031',
#  '300197',
#  '300539',
#  '600831',
#  '603421',
#  '603797',
#  '600233',
#  '002839',
#  '002787',
#  '002807',
#  '603518',
#  '300388',
#  '300473',
#  '601727',
#  '603677',
#  '002793',
#  '603569',
#  '601012',
#  '603568',
#  '603588',
#  '603023',
#  '300568',
#  '002815',
#  '002100',
#  '603055',
#  '002142',
#  '601929',
#  '601127',
#  '600483',
#  '002728',
#  '002658',
#  '300407',
#  '002865',
#  '600690',
#  '603816',
#  '000001',
#  '601233',
#  '603019',
#  '002758',
#  '603345',
#  '600908',
#  '300618',
#  '601818',
#  '002179',
#  '603989',
#  '600863',
#  '002318',
#  '600755',
#  '002823',
#  '002562',
#  '603179',
#  '000783',
#  '002741',
#  '600183',
#  '601211',
#  '603618',
#  '002013',
#  '603738',
#  '000861',
#  '601966',
#  '603225',
#  '000623',
#  '600998',
#  '300422',
#  '600566',
#  '002273',
#  '002258',
#  '002717',
#  '603601',
#  '002271',
#  '002753',
#  '603027',
#  '002078',
#  '600398',
#  '002542',
#  '601238',
#  '002472',
#  '002597',
#  '002008',
#  '002772',
#  '600185',
#  '002279',
#  '603822',
#  '601222',
#  '002460',
#  '002707',
#  '002284',
#  '002527',
#  '600271',
#  '002245',
#  '300433',
#  '000700',
#  '002325',
#  '002496']

# %%
import tushare as ts

# %%
basic_df = ts.get_stock_basics()

# %%
basic_df.head()
# Out:
#         name industry area       pe  outstanding  totals    ...     perundp    rev  profit    gpr    npr   holders
# code                                                        ...
# 600035  楚天高速       路桥   湖北    11.49        15.27   17.28    ...        1.30  20.81    1.61  39.71  22.33   68217.0
# 600226  瀚叶股份     农药化肥   浙江    50.51        19.93   31.39    ...        0.24 -28.02   -3.02  43.55  29.95   33932.0
# 002011  盾安环境     工程机械   浙江   107.07         8.41    9.17    ...        1.34  15.06  -28.73  14.74   0.61   71700.0
# 000839  中信国安      综合类   北京  3655.40        39.19   39.20    ...        0.29  -7.12  -97.80  14.93   0.18  221134.0
# 000609  中迪投资     区域地产   北京     0.00         2.92    2.99    ...        3.62 -91.88 -105.16  21.97 -32.38   23481.0
#
# [5 rows x 22 columns]

# %%
basic_df_reset = basic_df.reset_index()

# %%
basic_df_reset.head()
# Out:
#      code  name industry area       pe  outstanding    ...     perundp    rev  profit    gpr    npr   holders
# 0  600035  楚天高速       路桥   湖北    11.49        15.27    ...        1.30  20.81    1.61  39.71  22.33   68217.0
# 1  600226  瀚叶股份     农药化肥   浙江    50.51        19.93    ...        0.24 -28.02   -3.02  43.55  29.95   33932.0
# 2  002011  盾安环境     工程机械   浙江   107.07         8.41    ...        1.34  15.06  -28.73  14.74   0.61   71700.0
# 3  000839  中信国安      综合类   北京  3655.40        39.19    ...        0.29  -7.12  -97.80  14.93   0.18  221134.0
# 4  000609  中迪投资     区域地产   北京     0.00         2.92    ...        3.62 -91.88 -105.16  21.97 -32.38   23481.0
#
# [5 rows x 23 columns]

# %%
zg_df = basic_df_reset[basic_df_reset['code'].isin(zg_list)]

# %%
zg_df.head()
# Out:
#        code  name industry area      pe  outstanding    ...     perundp    rev  profit    gpr    npr   holders
# 29   300539  横河模具       塑料   浙江  196.55         0.61    ...        0.71  12.50  -53.60  21.24   3.17   12514.0
# 48   002460  赣锋锂业      小金属   江西   26.42         8.01    ...        2.10  26.44   10.26  38.46  30.79  177044.0
# 72   002758  华通医药     医药商业   浙江   62.78         1.79    ...        1.03  11.36  -20.00  14.71   2.44   19033.0
# 156  603313   梦百合     家居用品   江苏   41.45         0.82    ...        1.78  26.84  -23.84  30.10   5.25   19492.0
# 182  000070  特发信息     通信设备   深圳   46.63         6.00    ...        1.12   7.25   -4.40  14.93   4.08   73390.0
#
# [5 rows x 23 columns]

# %%
len(zg_df)
# Out:
# 122

# %%
zg_df['outstanding'].mean()
# Out:
# 16.922868852459015

# %%
zg_df['outstanding'].min()
# Out:
# 0.38

# %%
zg_df['outstanding'].idxmin()
# Out:
# 1175

# %%
zg_df.loc[1175]
# Out:
# code                  002865
# name                    钧达股份
# industry                汽车配件
# area                      海南
# pe                     50.18
# outstanding             0.38
# totals                  1.22
# totalAssets           170365
# liquidAssets         94426.3
# fixedAssets            36444
# reserved             38598.5
# reservedPerShare        3.17
# esp                    0.321
# bvps                    7.56
# pb                      2.84
# timeToMarket        20170425
# undp                 35043.5
# perundp                 2.88
# rev                    -4.38
# profit                  1.28
# gpr                    23.22
# npr                     5.39
# holders                18591
# Name: 1175, dtype: object

# %%
engine_daily = get_engine('db_daily')
price_df = pd.read_sql('2019-03-13',con=engine_daily)
# Out:
# c:\python3_64\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xD6\\xD0\\xB9\\xFA\\xB1\\xEA...' for column 'VARIABLE_VALUE' at row 480")
#   result = self._query(query)

# %%
price_df.head()
# Out:
#    index    code  name  changepercent  trade      ...            amount    per    pb        mktcap           nmc
# 0      0  603999  读者传媒          1.070   6.61      ...       119326787.0  50.46  2.24  3.807360e+05  3.807360e+05
# 1      1  603998  方盛制药         -3.017   6.43      ...        44764170.0  45.93  2.65  2.807484e+05  2.734015e+05
# 2      2  603997  继峰股份         -2.343   9.17      ...        33055482.0  19.93  3.23  5.863419e+05  5.777100e+05
# 3      3  603996  中新科技         -4.694  10.76      ...       111244282.0  21.96  2.06  3.229614e+05  3.229614e+05
# 4      4  603993  洛阳钼业         -0.412   4.83      ...       925776520.0  34.50  2.53  1.043243e+07  8.532568e+06
#
# [5 rows x 16 columns]

# %%
price_df[price_df['code'].isin(zg_list)][['code','trade']]
# Out:
#         code  trade
# 7     603989  21.55
# 87    603822  30.36
# 91    603816  54.99
# 103   603797  13.56
# 119   603738  16.13
# 156   603677  15.38
# 159   603668   8.88
# 181   603626  10.66
# 183   603618   6.66
# 196   603601   9.04
# 204   603588  10.36
# 213   603569  12.87
# 214   603568  25.22
# 230   603518  16.15
# 250   603421  27.98
# 279   603345  34.68
# 292   603323   7.82
# 300   603313  25.25
# 305   603305  38.80
# 329   603228  65.49
# 332   603225  20.70
# 354   603179  18.12
# 414   603055  12.19
# 432   603027  19.83
# 435   603023   6.08
# 439   603019  58.30
# 470   601966  16.75
# 477   601929   3.05
# 503   601818   4.16
# 514   601727   6.03
# ...      ...    ...
# 2588  002542   5.90
# 2603  002527   7.08
# 2633  002496   2.88
# 2657  002472   7.54
# 2669  002460  29.64
# 2683  002446   9.98
# 2804  002325   3.86
# 2811  002318   8.10
# 2845  002284   6.07
# 2850  002279   9.40
# 2856  002273  13.89
# 2858  002271  18.92
# 2871  002258  15.90
# 2883  002245   5.33
# 2904  002224   7.16
# 2949  002179  43.00
# 2986  002142  19.57
# 2997  002131   2.51
# 3028  002100   9.46
# 3050  002078   6.95
# 3115  002013   7.63
# 3120  002008  42.05
# 3233  000861   2.99
# 3264  000811   7.11
# 3286  000783   7.55
# 3341  000700   3.88
# 3369  000665   9.11
# 3394  000623  18.25
# 3537  000070  16.29
# 3590  000001  12.37
#
# [122 rows x 2 columns]

# %%
for i in zg_df.index:
    p=price_df[price_df['code']==zg_df.loc[i]['code']]['trade'].values[0]
    ltgb=zg_df.loc[i]['outstanding']
    t=p*ltgb
    zg_df.loc[i,'liutong']=t
# Out:
# c:\python3_64\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
zg_df['liutong']=0
# Out:
# c:\python3_64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
zg_df.loc[1175,'price']
# Out:
# 0

# %%
zg_df.head()
# Out:
#        code  name industry area      pe  outstanding    ...     profit    gpr    npr   holders  price   liutong
# 29   300539  横河模具       塑料   浙江  196.55         0.61    ...     -53.60  21.24   3.17   12514.0      0    9.5221
# 48   002460  赣锋锂业      小金属   江西   26.42         8.01    ...      10.26  38.46  30.79  177044.0      0  237.4164
# 72   002758  华通医药     医药商业   浙江   62.78         1.79    ...     -20.00  14.71   2.44   19033.0      0   19.6542
# 156  603313   梦百合     家居用品   江苏   41.45         0.82    ...     -23.84  30.10   5.25   19492.0      0   20.7050
# 182  000070  特发信息     通信设备   深圳   46.63         6.00    ...      -4.40  14.93   4.08   73390.0      0   97.7400
#
# [5 rows x 25 columns]

# %%
del zg_df['price']

# %%
final_df = zg_df.reset_index(drop=True)

# %%
final_df.head()
# Out:
#      code  name industry area      pe  outstanding    ...       rev  profit    gpr    npr   holders   liutong
# 0  300539  横河模具       塑料   浙江  196.55         0.61    ...     12.50  -53.60  21.24   3.17   12514.0    9.5221
# 1  002460  赣锋锂业      小金属   江西   26.42         8.01    ...     26.44   10.26  38.46  30.79  177044.0  237.4164
# 2  002758  华通医药     医药商业   浙江   62.78         1.79    ...     11.36  -20.00  14.71   2.44   19033.0   19.6542
# 3  603313   梦百合     家居用品   江苏   41.45         0.82    ...     26.84  -23.84  30.10   5.25   19492.0   20.7050
# 4  000070  特发信息     通信设备   深圳   46.63         6.00    ...      7.25   -4.40  14.93   4.08   73390.0   97.7400
#
# [5 rows x 24 columns]

# %%
final_df.to_sql('tb_zhenggu_liutong',engine)
